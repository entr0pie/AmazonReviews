# %%
# Lendo a fonte de dados

import pandas as pd

df = pd.read_csv('assets/amazon_cells_labelled.txt', sep="\t")
df
# Out:
#                                                   text  target
# 0    So there is no way for me to plug it in here i...       0
# 1                          Good case, Excellent value.       1
# 2                               Great for the jawbone.       1
# 3    Tied to charger for conversations lasting more...       0
# 4                                    The mic is great.       1
# ..                                                 ...     ...
# 995  The screen does get smudged easily because it ...       0
# 996  What a piece of junk.. I lose more calls on th...       0
# 997                       Item Does Not Match Picture.       0
# 998  The only thing that disappoint me is the infra...       0
# 999  You can not answer calls with the unit, never ...       0
#
# [1000 rows x 2 columns]

# %%
# Checando o balanceamento

df.groupby('target').count()
# Out:
#         text
# target
# 0        500
# 1        500

# %%
# Separando em treino e teste o conjunto de dados

from sklearn.model_selection import train_test_split

X, y = df['text'], df['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
# 521    Thanks again to Amazon for having the things I...
# 737    The tracfonewebsite is user friendly and makes...
# 740               I would highly recommend this product.
# 660    This does not fit the Palm Tungsten E2 and it ...
# 411          I highly recommend this device to everyone!
#                              ...
# 468    I find this inexcusable and so will probably b...
# 935    However, after about a year, the fliptop start...
# 428                                    IT'S REALLY EASY.
# 7            If you are Razr owner...you must have this!
# 155    This phone is very fast with sending any kind ...
# Name: text, Length: 300, dtype: object

# %%
# Vetorizando com o TF-IDF

from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)
# Out:
# <300x1500 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2394 stored elements in Compressed Sparse Row format>

# %%
# Criando o modelo

from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train_tfidf, y_train)
model
# Out:
# RandomForestClassifier()

# %%
# Prevendo qual a chance de ser uma boa avaliação

y_pred = model.predict(X_test_tfidf)
df_y_pred = pd.DataFrame(y_proba)

df_y_pred
# Out:
#      0
# 0    1
# 1    1
# 2    1
# 3    0
# 4    1
# ..  ..
# 295  1
# 296  0
# 297  1
# 298  0
# 299  1
#
# [300 rows x 1 columns]

# %%
# Calculando Métricas

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1_score = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)

pd.DataFrame({
    'Accuracy': [accuracy],
    'Precision': [precision],
    'Recall': [recall],
    'F1 Score': [f1_score],
    'Area Under ROC Curve': [roc_auc],
})
# Out:
#    Accuracy  Precision   Recall  F1 Score  Area Under ROC Curve
# 0      0.78   0.814286  0.74026   0.77551              0.781089

# %%
# Criando o histograma para curva ROC

import seaborn as sns
import matplotlib.pyplot as plt

y_pred = model.predict_proba(X_test_tfidf)

df_y_pred = pd.DataFrame(y_pred)
df_y_pred["Categoria"] = "População Geral"

index_reseted_dataframe = y_test.reset_index(drop=True)
filtered_dataframe = pd.DataFrame(y_pred[indexed_reseted_dataframe == 1])
filtered_dataframe["Categoria"] = "Casos positivos"

combined_dataframe = pd.concat([df_y_pred, filtered_dataframe], ignore_index=True)

sns.histplot(data=combined_dataframe, x=1, hue='Categoria', multiple="dodge", shrink=.8, bins=10 )

plt.title("Gráfico para Pontos de Corte")
plt.xlabel("População geral")
plt.ylabel("Contagem total")

plt.show()
